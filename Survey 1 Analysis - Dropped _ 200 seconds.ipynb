# %% [markdown]
# # Pre-Processing Data

# %% [markdown]
# ## Import Data
# This data was collected through "Survey 1 - Rating Facebook Content Appropriateness"

# %%
# General Libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import time

# SK Learn Libraries
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import metrics

# Other Libraries
from astropy.table import Table
from astropy.io import ascii
from collections import Counter
from collections import OrderedDict

# %%
# Create Bag of Words Numpy Array
df = pd.read_csv("Data/results.csv", delimiter=",")

# %% [markdown]
# ## Edit Data

# %% [markdown]
# ### Drop rows that do not contain information about question responses.

# %% [markdown]
# Drop the first 151 rows of responses due to survey response issues that would violate research integrity.

# %%
# Drop Rows
drop_rows = list(range(0, 151))
df.drop(drop_rows, inplace=True)
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Drop rows for responses that took less than 200 seconds to complete

# %%
drop_200 = []
for i in range(2, len(df.index)):
    if int(df.iloc[i, 5]) < 200: 
        drop_200.append(i)
df.drop(drop_200, inplace=True)

# %%
df
# Out:
#                StartDate              EndDate      Status IPAddress Progress  \
# 0    2019-03-19 08:30:37  2019-03-19 14:54:15  IP Address   *******      100
# 1    2019-03-19 14:51:08  2019-03-19 14:56:47  IP Address   *******      100
# 2    2019-03-19 15:05:12  2019-03-19 15:13:50  IP Address   *******      100
# 3    2019-03-19 15:11:24  2019-03-19 15:15:48  IP Address   *******      100
# 4    2019-03-19 14:53:38  2019-03-19 15:16:50  IP Address   *******      100
# 5    2019-03-19 15:16:55  2019-03-19 15:23:44  IP Address   *******      100
# 6    2019-03-19 15:14:34  2019-03-19 15:28:44  IP Address   *******      100
# 7    2019-03-19 15:42:50  2019-03-19 15:48:39  IP Address   *******      100
# 8    2019-03-19 14:34:16  2019-03-19 15:56:41  IP Address   *******      100
# 9    2019-03-19 15:57:34  2019-03-19 16:16:17  IP Address   *******      100
# 10   2019-03-19 16:05:37  2019-03-19 16:18:06  IP Address   *******      100
# 11   2019-03-19 16:09:19  2019-03-19 16:24:42  IP Address   *******      100
# 12   2019-03-19 13:42:20  2019-03-19 16:31:18  IP Address   *******      100
# 13   2019-03-19 16:27:48  2019-03-19 16:36:15  IP Address   *******      100
# 14   2019-03-19 13:30:17  2019-03-19 16:54:58  IP Address   *******      100
# 15   2019-03-19 08:38:50  2019-03-19 17:04:25  IP Address   *******      100
# 16   2019-03-19 10:01:45  2019-03-19 17:19:21  IP Address   *******      100
# 17   2019-03-19 17:13:25  2019-03-19 17:25:38  IP Address   *******      100
# 18   2019-03-19 14:57:01  2019-03-19 17:31:41  IP Address   *******      100
# 19   2019-03-19 17:24:21  2019-03-19 17:31:45  IP Address   *******      100
# 20   2019-03-19 17:26:20  2019-03-19 17:34:01  IP Address   *******      100
# 22   2019-03-19 14:56:02  2019-03-19 17:48:34  IP Address   *******      100
# 23   2019-03-19 12:17:37  2019-03-19 17:50:32  IP Address   *******      100
# 24   2019-03-19 17:56:28  2019-03-19 18:05:38  IP Address   *******      100
# 25   2019-03-19 18:13:55  2019-03-19 18:18:39  IP Address   *******      100
# 26   2019-03-19 18:13:29  2019-03-19 18:20:23  IP Address   *******      100
# 27   2019-03-19 16:19:51  2019-03-19 18:51:05  IP Address   *******      100
# 29            *******     ...         7    7    1    7    7    3  NaN  Yes
# 30            *******     ...         4    5    6    3    3    6    5   No
# ..                ...     ...       ...  ...  ...  ...  ...  ...  ...  ...
# 478           *******     ...         3    5    4    4    5    6    4  NaN
# 479           *******     ...         1    1    1    7    5    1    1   No
# 480           *******     ...         1    1    2    2    1    2    1   No
# 481           *******     ...         4    4  NaN  NaN  NaN  NaN  NaN  NaN
# 484           *******     ...         1    2    3    4    2    2    2  NaN
# 485           *******     ...       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 486           *******     ...         1    1    1    5    1    1    1  NaN
# 487           *******     ...         2    5    1    5    3    2    3  Yes
# 490           *******     ...         2    5    4    5    5    2  NaN  Yes
# 492           *******     ...       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 493           *******     ...         2    2  NaN  NaN  NaN  NaN  NaN  NaN
# 495           *******     ...         1    4    1    1    1    4    1   No
# 496           *******     ...       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 497           *******     ...         7    7  NaN  NaN  NaN  NaN  NaN  NaN
# 498           *******     ...         1    4    1    4    4    1    2  NaN
# 503           *******     ...         2    4    4    5    4    3    3  Yes
# 509           *******     ...       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 510           *******     ...       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 511           *******     ...       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 515           *******     ...       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 518           *******     ...       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 519           *******     ...         5    5    1    1    1    2    1  NaN
# 521           *******     ...         3    7    3    4    3    1    2  NaN
# 522           *******     ...       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 523           *******     ...         5    3    5    5    5    6    5  NaN
# 524           *******     ...       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 528           *******     ...       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 529           *******     ...       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 530           *******     ...       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 531           *******     ...         1    1    1    1    1    1    1  Yes
#
#                                                    Q40 Q40 - Topics
# 0                                                  NaN          NaN
# 1                                                  NaN          NaN
# 2                                                  NaN          NaN
# 3                                                  NaN          NaN
# 4    https://m.facebook.com/mara.harwin?tsid=0.3064...      Unknown
# 5                                                  NaN          NaN
# 6       https://www.facebook.com/slumdawg.millieonaire      Unknown
# 7                                                  NaN          NaN
# 8            https://www.facebook.com/jack.wolfgramm.9      Unknown
# 9                                                  NaN          NaN
# 10                                                 NaN          NaN
# 11                                                 NaN          NaN
# 12                                                 NaN          NaN
# 13                                                 NaN          NaN
# 14                                                 NaN          NaN
# 15                                                 NaN          NaN
# 16                                                 NaN          NaN
# 17                https://m.facebook.com/samuel.oh.330      Unknown
# 18                  https://www.facebook.com/maganha38      Unknown
# 19                                                 NaN          NaN
# 20                                                 NaN          NaN
# 22             https://www.facebook.com/sarah.eagan.54      Unknown
# 23                                                 NaN          NaN
# 24                                                 NaN          NaN
# 25                                                 NaN          NaN
# 26                                                 NaN          NaN
# 27                                                 NaN          NaN
# 28                                                 NaN          NaN
# 29   https://www.facebook.com/profile.php?id=573484349      Unknown
# 30                                                 NaN          NaN
# ..                                                 ...          ...
# 478                                                NaN          NaN
# 479                                                NaN          NaN
# 480                                                NaN          NaN
# 481                                                NaN          NaN
# 484                                                NaN          NaN
# 485                                                NaN          NaN
# 486                                                NaN          NaN
# 487            https://www.facebook.com/natasha.skov.7          NaN
# 490                                                NaN          NaN
# 492                                                NaN          NaN
# 493                                                NaN          NaN
# 495                                                NaN          NaN
# 496                                                NaN          NaN
# 497                                                NaN          NaN
# 498                                                NaN          NaN
# 503                                                NaN          NaN
# 509                                                NaN          NaN
# 510                                                NaN          NaN
# 511                                                NaN          NaN
# 515                                                NaN          NaN
# 518                                                NaN          NaN
# 519                                                NaN          NaN
# 521                                                NaN          NaN
# 522                                                NaN          NaN
# 523                                                NaN          NaN
# 524                                                NaN          NaN
# 528                                                NaN          NaN
# 529                                                NaN          NaN
# 530                                                NaN          NaN
# 531                                                NaN          NaN
#
# [465 rows x 46 columns]

# %% [markdown]
# ### Restructure data

# %%
# Export edited data 
df.to_csv('Data/results_edited_dropped_200.csv', index=False)

# %%
# Drop Columns
df = pd.read_csv("Data/results_edited_dropped_200.csv", delimiter=",")
drop_columns = ['StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress', 'Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId', 'RecipientLastName', 'RecipientFirstName', 'RecipientEmail', 'ExternalReference', 'LocationLatitude', 'LocationLongitude', 'DistributionChannel', 'UserLanguage', 'Q39', 'Q40', 'Q40 - Topics', 'Q41']
df = df.drop(columns=drop_columns, axis=1)
df.shape
# Out:
# (465, 25)

# %% [markdown]
# ### Replace remaining NaNs

# %%
# Replace NaN's with the mode
# df = df.fillna(df.mode().iloc[0])
df.dropna(inplace=True)
df
# Out:
#       Q3   Q4   Q5   Q6   Q7  Q10  Q12  Q14  Q16  Q18 ...   Q27  Q28  Q29  \
# 0    2.0  1.0  3.0  5.0  2.0  2.0  4.0  6.0  3.0  3.0 ...   3.0  2.0  4.0
# 1    1.0  6.0  1.0  2.0  1.0  5.0  2.0  1.0  1.0  2.0 ...   1.0  7.0  6.0
# 2    5.0  7.0  6.0  1.0  5.0  7.0  3.0  3.0  2.0  5.0 ...   2.0  7.0  4.0
# 3    1.0  3.0  4.0  2.0  2.0  5.0  1.0  4.0  2.0  2.0 ...   2.0  4.0  1.0
# 4    1.0  2.0  4.0  1.0  6.0  6.0  3.0  1.0  2.0  5.0 ...   1.0  6.0  5.0
# 5    4.0  7.0  7.0  3.0  3.0  6.0  1.0  1.0  1.0  2.0 ...   1.0  7.0  5.0
# 7    3.0  6.0  5.0  1.0  3.0  6.0  3.0  3.0  1.0  3.0 ...   1.0  6.0  5.0
# 8    7.0  7.0  2.0  1.0  4.0  3.0  1.0  3.0  2.0  2.0 ...   1.0  7.0  7.0
# 9    5.0  6.0  4.0  2.0  3.0  4.0  2.0  2.0  3.0  5.0 ...   3.0  7.0  5.0
# 10   5.0  7.0  5.0  1.0  5.0  5.0  3.0  3.0  3.0  6.0 ...   1.0  3.0  2.0
# 11   3.0  4.0  1.0  1.0  2.0  6.0  2.0  2.0  2.0  6.0 ...   1.0  7.0  5.0
# 12   4.0  6.0  4.0  4.0  5.0  5.0  3.0  2.0  2.0  4.0 ...   3.0  6.0  7.0
# 13   4.0  6.0  2.0  1.0  2.0  5.0  1.0  2.0  1.0  4.0 ...   1.0  6.0  5.0
# 14   5.0  5.0  1.0  1.0  5.0  5.0  1.0  3.0  2.0  2.0 ...   2.0  6.0  7.0
# 15   7.0  3.0  7.0  7.0  3.0  3.0  7.0  7.0  7.0  7.0 ...   7.0  4.0  2.0
# 16   2.0  6.0  1.0  1.0  2.0  3.0  1.0  2.0  1.0  2.0 ...   1.0  4.0  1.0
df.to_csv('Data/results_no_metadata_dropped_200.csv', index=False)

# %%
# Convert all data to integers
df = pd.read_csv("Data/results_no_metadata_dropped_200.csv", delimiter=",", dtype=int)
response_numbers = len(df)
df = df.transpose()
index = df.index.values
df.shape
# Out:
# (25, 408)

# %% [markdown]
# ### Isolate Community Standards

# %%
def isolate_data(a, b):
    data = df.iloc[a:b]
    return data, data.index.values

# %%
hate, hate_index = isolate_data(0, 5)
nudity, nudity_index = isolate_data(5, 10)
cruel, cruel_index = isolate_data(10, 15)
spam, spam_index = isolate_data(15, 20)
false, false_index = isolate_data(20, 25)

# %% [markdown]
# ## Analyze Data

# %% [markdown]
# ### Means and Variances

# %%
# Define function for getting means and variances
def get_stat(data):
    means = []
    sds = []    
    for i in range(len(data)):
        m = np.round(np.mean(data.iloc[i]), decimals=4)
        sd = np.round(np.std(data.iloc[i]), decimals=4)
        means.append(m)
        sds.append(sd) 
    return means, sds

# %%
# Get means and standard deviations for overall dataset
means, sds = get_stat(df)   

# Get means and standard deviations for each Community Standard
hate_means, hate_sds = get_stat(hate)
nudity_means, nudity_sds = get_stat(nudity)
cruel_means, cruel_sds = get_stat(cruel)
spam_means, spam_sds = get_stat(spam)
false_means, false_sds = get_stat(false)

#for i in range(len(index)):
    #print('%s: means=%.2f sd=%.2f' %(index[i], means[i], sds[i]))

# %% [markdown]
# ### Figures for Means and Variances

# %%
# Define function to create bar graph with error bars   
def plot_figs(index, means, sds, standard, file_name):
    fig = plt.figure(figsize=(10,5))
    plt.bar(index, means, yerr=sds, align='center', alpha=0.8, ecolor='black', capsize=10, color='tab:green')
    plt.ylabel('Rating of Facebook Posts')
    plt.xticks(index)
    plt.title('Means and Standard Devations for %s (Response Time > 200 sec)' % standard)
    plt.tight_layout()
    plt.savefig('Figures_dropped_200/%s_bar_plot_with_error_bars_dropped_200.png' % file_name, overwrite=True)
    plt.show()

# Plot and save figures
plot_figs(index, means, sds, 'All Five Standards', 'all')  
plot_figs(hate_index, hate_means, hate_sds, 'Hate Speech', 'hate')
plot_figs(nudity_index, nudity_means, nudity_sds, 'Adulty Nudity and Sexual Activity', 'nudity')
plot_figs(cruel_index, cruel_means, cruel_sds, 'Cruel and Insensitive Content', 'cruel')
plot_figs(spam_index, spam_means, spam_sds, 'Spam', 'spam')
plot_figs(false_index, false_means, false_sds, 'False News', 'false')

# %%
def create_stat_charts(index, means, sds, standard, file_name):
    t = Table([index, means, sds], names=('index', 'means', 'sds'), meta={'name': 'Table on Survey 1 %s Means and Variances (Response Time > 200 seconds)' % file_name})
    ascii.write(t, 'Tables_dropped_200/table_of_%s_means_sds_dropped_200.csv' % file_name, format='csv', fast_writer=False, overwrite=True)
    print(t)
# Create charts with means and variances
create_stat_charts(index, means, sds, 'All', 'all')
create_stat_charts(hate_index, hate_means, hate_sds, 'Hate Speech', 'hate')
create_stat_charts(nudity_index, nudity_means, nudity_sds, 'Adult Nudity and Sexual Activity', 'nudity')
create_stat_charts(cruel_index, cruel_means, cruel_sds, 'Cruel and Insensitive Speech', 'cruel')
create_stat_charts(spam_index, spam_means, spam_sds, 'Spam', 'spam')
create_stat_charts(false_index, false_means, false_sds, 'False News', 'false')
# Out:
# index means   sds
# ----- ------ ------
#    Q3 3.5417 1.6622
#    Q4 5.8113  1.474
#    Q5 3.1716 1.9691
#    Q6 1.4559 1.1259
#    Q7 3.0515 1.8721
#   Q10   4.25 1.7267
#   Q12  1.875 1.2234
#   Q14 2.2034 1.5531
#   Q16 1.7328 1.2146
#   Q18 3.6544 1.7838
#   ...    ...    ...
#   Q25  4.326 1.7696
#   Q27 1.6569 1.2485
#   Q28 5.3946 1.9688
#   Q29 4.7328 1.9212
#   Q30 2.4902 1.7363
#   Q31 3.7132 1.9775
#   Q33 2.7132 1.6053
#   Q34 4.0882 1.7453
#   Q35  3.549 1.8264
#   Q36 2.2279 1.4483
#   Q37 2.1544  1.463
# Length = 25 rows
# index means   sds
# ----- ------ ------
#    Q3 3.5417 1.6622
#    Q4 5.8113  1.474
#    Q5 3.1716 1.9691
#    Q6 1.4559 1.1259
#    Q7 3.0515 1.8721
# index means   sds
# ----- ------ ------
#   Q10   4.25 1.7267
#   Q12  1.875 1.2234
#   Q14 2.2034 1.5531
#   Q16 1.7328 1.2146
#   Q18 3.6544 1.7838
# index means   sds
# ----- ------ ------
#   Q21 4.4338 1.8232
#   Q22 2.4387 1.6015
#   Q23 2.4289 1.5243
#   Q24  3.299 1.8901
#   Q25  4.326 1.7696
# index means   sds
# ----- ------ ------
#   Q27 1.6569 1.2485
#   Q28 5.3946 1.9688
#   Q29 4.7328 1.9212
#   Q30 2.4902 1.7363
#   Q31 3.7132 1.9775
# index means   sds
# ----- ------ ------
#   Q33 2.7132 1.6053
#   Q34 4.0882 1.7453
#   Q35  3.549 1.8264
#   Q36 2.2279 1.4483
#   Q37 2.1544  1.463

# %% [markdown]
# ### Bar Graphs for Each Question

# %%
def get_counts(data):
    prev = 0
    final_counts = []
    counts = Counter(data.iloc[0])
    counts = OrderedDict(sorted(counts.items()))
    for key, value in counts.items():
        if key-1 != prev:
            final_counts.append(0)
        prev = key
        final_counts.append(value)
    return final_counts

def graph(data):
    for i in range(25):
        data, index = isolate_data(i, i+1)
        counts = get_counts(data)
        bar_spacing = list(range(1, 8, 1))
        plt.bar(bar_spacing, counts, width=0.75, color='tab:green')
        for j in range(7):
            plt.text(x=bar_spacing[j]-0.2, y=counts[j]+6, s=counts[j], fontsize=12)
        plt.xlabel('Rankings', fontsize=14)
        plt.ylabel('Frequencies', fontsize=14)
        plt.title('Rankings for Survey %s (Response Time > 200 Seconds)' % index[0], fontsize=14)
        plt.text(3, 330,'Number of Responses = %i' % response_numbers, fontsize=14)
        plt.text(5, 300,'mean = %.4f' % means[i], fontsize=14)
        plt.text(5, 270,'sd = %.4f' % sds[i], fontsize=14)
        plt.axis([0, 8, 0, 350])
        plt.grid(True, ls="-", color='0.8')
        plt.savefig('Figures_dropped_200/%s_ranking_bar_plot_dropped_200.png' % index[0], overwrite=True)
        plt.show()
        
graph(df)
